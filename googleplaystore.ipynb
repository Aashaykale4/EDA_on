# %% [markdown]
# EDA >>Exploratory Data Analysis
# --profilr of data
# --statistical vased analysis
# --graphs bsased analysis

# %%
import pandas as pd
# >>graphs 
# >>scatterplot=to understand relationship btn 2 variable
# >>line chart =whenever on x axis we have time component
# >>bar chart =for categorical data
# >>count plot=for categorical data
# >>pie chart =for distribution of different unque classes
# >>box plot and violin plot =to determine outlier
# >>histogram=for continous plot
# >>heat map=to understand the correlation
# >>pairplot=all numerical relationship in one plot
# >>join plot =relationship and distibutuion of data
# >>swarmplot/relplot=scatterplot
# >>lmplot=reg line
df=pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# EDA and data preparation are different

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# Check duplicates

# %%
df[df.duplicated()].head()
# Out:
#                               App  Category  Rating Reviews  \
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 236                           Box  BUSINESS     4.2  159872
# 239            Google My Business  BUSINESS     4.4   70991
# 256           ZOOM Cloud Meetings  BUSINESS     4.4   31614
# 261     join.me - Simple Meetings  BUSINESS     4.0    6989
#
#                    Size     Installs  Type Price Content Rating    Genres  \
# 229  Varies with device   5,000,000+  Free     0       Everyone  Business
# 236  Varies with device  10,000,000+  Free     0       Everyone  Business
# 239  Varies with device   5,000,000+  Free     0       Everyone  Business
# 256                 37M  10,000,000+  Free     0       Everyone  Business
# 261  Varies with device   1,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver         Android Ver
# 229  February 26, 2018  Varies with device        4.0.3 and up
# ...

# %%
df.duplicated().sum()
# Out:
# 483

# %%
#drop duplicate values
# df.drop_duplicates(inplace=True)
df.shape
# Out:
# (10841, 13)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Rating'] #continous variable>>1.1,1.2,3.4,4.5
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
df.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df.Reviews.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[~df.Reviews.str.isnumeric()] #not numeric in reviews
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy=df.copy()
df_copy[~df_copy['Reviews'].apply(lambda x:x.isnumeric())]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# drop non numeric row

# %%
df_copy.drop(df_copy.index[10472],inplace=True)
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df_copy.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10840, dtype: object

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# replaceing

# %%
df_copy['Size']=df_copy['Size'].str.replace('M',"000")
df_copy['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201k', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
df_copy['Size']=df_copy['Size'].str.replace('k','')
df_copy['Size']=df_copy['Size'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 df_copy['Size']=df_copy['Size'].str.replace('k','')
# ----> 2 df_copy['Size']=df_copy['Size'].astype(float)
#
# File c:\Users\A\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\A\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# def size_process(item):
#     if str(item)[-1]=='K':
#         res=str(item).replace('k','')

# %%
df_copy['Installs']=df_copy['Installs'].str.replace('+','').str.replace(',','')
df_copy['Installs'].astype(int)
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10840, dtype: int32

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy['Price']=df_copy['Price'].str.replace('$','')
df_copy['Price']=df_copy['Price'].astype(float)

# %%
df_copy['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
categorical_feature =[feature for feature in df_copy.columns if df_copy[feature].dtype=='O']

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_feature=[feature for feature in df_copy.columns if df_copy[feature].dtype!='O' ]

# %%
numerical_feature
# Out:
# ['Rating']

# %%
df_copy['Type'].value_counts(normalize= True)
# Out:
# Type
# Free    0.926192
# Paid    0.073808
# Name: proportion, dtype: float64

# %%
import seaborn as sns
sns.countplot(x=df_copy['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df_copy['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10840, dtype: object

# %%
import seaborn as sns
sns.countplot(x=df_copy['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.histplot(df_copy['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.kdeplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],autopct='%1.1f',figsize=(15,15))
# Out:
# <Axes: ylabel='count'>

# %%
df_copy['Category'].value_counts().plot.bar(figsize=(15,15))
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# TOP 10

# %%
df_copy['Category'].value_counts()[:10].plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# Highest Installation

# %%
df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()[:10]
# Out:
#               Category                                           Installs
# 0         PRODUCTIVITY  500,000,000+10,000,000+100,000,000+10,000,000+...
# 1               BEAUTY  500,000+1,000,000+100,000+500,000+1,000,000+50...
# 2               FAMILY  50,000,000+10,000,000+100,000,000+1,000,000+5,...
# 3              WEATHER  50,000,000+1,000,000+50,000,000+10,000+10,000,...
# 4      PERSONALIZATION  50,000,000+1,000,000+100,000,000+5,000,000+100...
# 5   LIBRARIES_AND_DEMO  50,000+10,000+100,000+1,000+100,000+10,000+100...
# 6            LIFESTYLE  5,000,000+10,000,000+100,000+10,000,000+5,000,...
# 7  BOOKS_AND_REFERENCE  100,000,000+50,000+100,000+10,000,000+100,000,...
# 8  MAPS_AND_NAVIGATION  100,000,000+5,000,000+10,000,000+10,000,000+5,...
# 9            EDUCATION  100,000,000+10,000,000+100,000+5,000,000+10,00...

# %% [markdown]
# TOP 5 Installed apps in each popular category Type

# %%
df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=True).reset_index()[:5]
# Out:
#           Category  Type                                           Installs
# 0           EVENTS  Paid                                                 1+
# 1        EDUCATION  Paid                       1,000+1,000+500,000+100,000+
# 2           SOCIAL  Paid                                     1,000+5,000+0+
# 3          MEDICAL  Free  1,000,000+1,000,000+1,000,000+1,000,000+1,000,...
# 4  PERSONALIZATION  Paid  1,000,000+1,000,000+10,000+10,000+100,000+100+...
